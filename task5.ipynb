# %%
import pandas as pd

# %%
students = {
    "Name": ["Ali", "Sara", "Omar", "Lina", "Youssef", "Mariam"],
    "Age": [20, 21, 19, 22, 20, 21],
    "Grade": [85, 92, 78, 95, 88, 73],
    "Department": ["CS", "AI", "CS", "DS", "AI", "DS"]
}
df = pd.DataFrame(students)

# %%
#2
df.iloc[0:3]
# Out:
#    Name  Age  Grade Department
# 0   Ali   20     85         CS
# 1  Sara   21     92         AI
# 2  Omar   19     78         CS

# %%
df.iloc[-2:]
# Out:
#       Name  Age  Grade Department
# 4  Youssef   20     88         AI
# 5   Mariam   21     73         DS

# %%
df.shape
# Out:
# (6, 4)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Grade', 'Department'], dtype='str')

# %%
df.dtypes
# Out:
# Name            str
# Age           int64
# Grade         int64
# Department      str
# dtype: object

# %%
#shape returns a tuple of the dimensions of the dataframe (number of rows , number of columns)
#size returns an integer of the total number of elemets in dataframe
#len(df) returns an integer of the number of rows

# %%
#3
df["Name"]
# Out:
# 0        Ali
# 1       Sara
# 2       Omar
# 3       Lina
# 4    Youssef
# 5     Mariam
# Name: Name, dtype: str

# %%
df[["Name","Grade"]]
# Out:
#       Name  Grade
# 0      Ali     85
# 1     Sara     92
# 2     Omar     78
# 3     Lina     95
# 4  Youssef     88
# 5   Mariam     73

# %%
df.iloc[0:2]
# Out:
#    Name  Age  Grade Department
# 0   Ali   20     85         CS
# 1  Sara   21     92         AI

# %%
df.loc[0:2,'Grade']
# Out:
# 0    85
# 1    92
# 2    78
# Name: Grade, dtype: int64

# %%
filt = df["Grade"] > 85
df.loc[filt]
# Out:
#       Name  Age  Grade Department
# 1     Sara   21     92         AI
# 3     Lina   22     95         DS
# 4  Youssef   20     88         AI

# %%
filt = df["Department"] == "AI"
df.loc[filt]
# Out:
#       Name  Age  Grade Department
# 1     Sara   21     92         AI
# 4  Youssef   20     88         AI

# %%
filt = df['Grade'] >=60
df.loc[filt,'Passed'] = "Yes"
filt = ~(df['Grade'] >= 60)
df.loc[filt,'Passed'] = "No"

# %%
df
# Out:
#       Name  Age  Grade Department Passed
# 0      Ali   20     85         CS    Yes
# 1     Sara   21     92         AI    Yes
# 2     Omar   19     78         CS    Yes
# 3     Lina   22     95         DS    Yes
# 4  Youssef   20     88         AI    Yes
# 5   Mariam   21     73         DS    Yes

# %%
filt = df['Grade'] >= 90
df.loc[filt,'Grade_Level'] = "Excellent"
filt =  (df['Grade'] >=80) & (df['Grade'] < 90) 
df.loc[filt,'Grade_Level'] = "Good"
filt = ~(df['Grade'] >=80)
df.loc[filt,'Grade_Level'] = "Average"

# %%
df
# Out:
#       Name  Age  Grade Department Passed Grade_Level
# 0      Ali   20     85         CS    Yes        Good
# 1     Sara   21     92         AI    Yes   Excellent
# 2     Omar   19     78         CS    Yes     Average
# 3     Lina   22     95         DS    Yes   Excellent
# 4  Youssef   20     88         AI    Yes        Good
# 5   Mariam   21     73         DS    Yes     Average

# %%
df.replace((df.loc[2,'Department']),"AI",inplace=True)
# Out:
#       Name  Age  Grade Department Passed Grade_Level
# 0      Ali   20     85         AI    Yes        Good
# 1     Sara   21     92         AI    Yes   Excellent
# 2     Omar   19     78         AI    Yes     Average
# 3     Lina   22     95         DS    Yes   Excellent
# 4  Youssef   20     88         AI    Yes        Good
# 5   Mariam   21     73         DS    Yes     Average

# %%
df
# Out:
#       Name  Age  Grade Department Passed Grade_Level
# 0      Ali   20     85         AI    Yes        Good
# 1     Sara   21     92         AI    Yes   Excellent
# 2     Omar   19     78         AI    Yes     Average
# 3     Lina   22     95         DS    Yes   Excellent
# 4  Youssef   20     88         AI    Yes        Good
# 5   Mariam   21     73         DS    Yes     Average

# %%
df["Grade"].mean()
# Out:
# np.float64(85.16666666666667)

# %%
df["Grade"].max()
# Out:
# np.int64(95)

# %%
df["Grade"].min()
# Out:
# np.int64(73)

# %%
index=df.index[df["Grade"]==df["Grade"].max()]
df.iloc[index]
# Out:
#    Name  Age  Grade Department Passed Grade_Level
# 3  Lina   22     95         DS    Yes   Excellent

# %%
grp = df.groupby("Department")
grp.get_group("AI")["Age"].mean()
# Out:
# np.float64(20.0)

# %%
grp.get_group("DS")["Age"].mean()
# Out:
# np.float64(21.5)

# %%
df["Department"].value_counts()
# Out:
# Department
# AI    4
# DS    2
# Name: count, dtype: int64

# %%
df_new = df.loc[df['Grade'] > 80, ["Name", "Grade", "Department"]].sort_values('Grade',ascending=False)

# %%
df_new
##########################
# Out:
#       Name  Grade Department
# 3     Lina     95         DS
# 1     Sara     92         AI
# 4  Youssef     88         AI
# 0      Ali     85         AI

# %%
#7
data = {
    "Name": ["Ali", "Sara", None, "Lina"],
    "Age": [20, None, 19, 22],
    "Grade": [85, 92, 78, None]
}
df_missing = pd.DataFrame(data)

# %%
df_missing.isna()
# Out:
#     Name    Age  Grade
# 0  False  False  False
# 1  False   True  False
# 2   True  False  False
# 3  False  False   True

# %%
df_missing.isna().sum()
# Out:
# Name     1
# Age      1
# Grade    1
# dtype: int64

# %%
(df_missing.isna().sum()).sum()
# Out:
# np.int64(3)

# %%
df_missing.loc[df_missing['Name'].isna(), 'Name'] = "Unknown"

# %%
df_missing
# Out:
#       Name   Age  Grade
# 0      Ali  20.0   85.0
# 1     Sara   NaN   92.0
# 2  Unknown  19.0   78.0
# 3     Lina  22.0    NaN

# %%
df_missing.loc[df_missing['Age'].isna(), 'Age'] = df_missing['Age'].mean()
df_missing.loc[df_missing['Grade'].isna(), 'Grade'] = df_missing['Grade'].mean()

# %%
df_missing
#########################################
# Out:
#       Name        Age  Grade
# 0      Ali  20.000000   85.0
# 1     Sara  20.333333   92.0
# 2  Unknown  19.000000   78.0
# 3     Lina  22.000000   85.0

# %%
#8
students_info = pd.DataFrame({
    "ID": [1, 2, 3, 4],
    "Name": ["Ali", "Sara", "Omar", "Lina"],
    "Department": ["CS", "AI", "CS", "DS"]
})

students_grades = pd.DataFrame({
    "ID": [1, 2, 3, 4],
    "Grade": [85, 92, 78, 95]
})

# %%
both=pd.merge(students_info,students_grades,on="ID")
both
# Out:
#    ID  Name Department  Grade
# 0   1   Ali         CS     85
# 1   2  Sara         AI     92
# 2   3  Omar         CS     78
# 3   4  Lina         DS     95

# %%
#9
new_students = pd.DataFrame({
    "ID": [5, 6],
    "Name": ["Youssef", "Mariam"],
    "Department": ["AI", "DS"]
})
both=pd.concat([both,new_students],axis=0,)

# %%
both
################################
# Out:
#    ID     Name Department  Grade
# 0   1      Ali         CS   85.0
# 1   2     Sara         AI   92.0
# 2   3     Omar         CS   78.0
# 3   4     Lina         DS   95.0
# 0   5  Youssef         AI    NaN
# 1   6   Mariam         DS    NaN

# %%
#10
grp1 = both.groupby("Department")
grp["Grade"].mean()
# Out:
# Department
# AI    92.0
# CS    81.5
# DS    95.0
# Name: Grade, dtype: float64

# %%
top = grp["Grade"].mean().idxmax()
top
# Out:
# 'DS'

# %%
both.to_csv('both.csv', index=False)
